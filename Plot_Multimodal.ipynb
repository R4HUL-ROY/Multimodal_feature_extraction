# %% [markdown]
# <a href="https://colab.research.google.com/github/R4HUL-ROY/Multimodal_feature_extraction/blob/main/Plot_Multimodal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
 
rf_accuracy = 78
svm_accuracy = 75
ann_accuracy =  70
  
# creating the dataset
data = {'Random Forest': rf_accuracy, 'SVM':svm_accuracy, 'ANN':ann_accuracy}


models = list(data.keys())
accuracy = list(data.values())
  
fig = plt.figure(figsize = (8, 4))
 
# creating the bar plot
plt.bar(models, accuracy , color ='maroon',
        width = 0.3)
 
plt.xlabel("models implemented")
plt.ylabel("accuracy")
plt.title("TFIDF - word embedding, (only Text modality)")
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

models = ['random forest', 'SVM', 'ANN']
accuracy = [78, 75, 70]
 
# Figure Size
fig, ax = plt.subplots(figsize =(10, 5))
 
# Horizontal Bar Plot
ax.barh(models, accuracy)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('models vs their accuracy in %',
             loc ='left', )
# Show Plot
plt.show()
